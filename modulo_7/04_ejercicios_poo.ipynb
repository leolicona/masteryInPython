# %% [markdown]
# <a href="https://colab.research.google.com/github/YOUR_USERNAME_AQUI/masteryInPython/blob/main/modulo_7/04_ejercicios_poo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Ejercicios Prácticos de POO

# %% [markdown]
# ## 🧠 Ejercicios de Refuerzo: Módulo 7 (POO)
#
# ### Ejercicio 1: El Sistema de Biblioteca
# Crea dos clases:
# 1. `Libro`: con atributos `titulo`, `autor` y `prestado` (booleano, por defecto False).
# 2. `Biblioteca`: con una lista de `Libros`. Debe tener métodos para `agregar_libro(libro)`, `prestar_libro(titulo)` y `devolver_libro(titulo)`.
# Escribe código para probar tu sistema agregando y prestando libros.

# %%
# Escribe tu código aquí
