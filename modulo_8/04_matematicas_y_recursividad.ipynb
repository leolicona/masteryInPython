# %% [markdown]
# <a href="https://colab.research.google.com/github/YOUR_USERNAME_AQUI/masteryInPython/blob/main/modulo_8/04_matematicas_y_recursividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Bootcamp: Matemáticas y Recursividad

# %% [markdown]
# ## Reto 1: Subiendo Escaleras
# **Tarea:**
# Se necesitan `n` pasos para llegar a la cima. Cada vez puedes subir 1 o 2 escalones. ¿De cuántas maneras distintas puedes llegar a la cima?
#
# **Ejemplo:**
# `n = 3` -> `3`
#
# **Entrada/Salida:**
# - `n`: integer
# - retorno: integer

# %%
def solucion(n):
    pass

# %% [markdown]
# ## Reto 2: Beneficio de Depósito
# **Tarea:**
# Has depositado una cantidad en el banco. Cada año el saldo aumenta en un porcentaje `rate`. Encuentra cuántos años tomará superar un `threshold`.
#
# **Ejemplo:**
# `deposit = 100, rate = 20, threshold = 170` -> `3` (años)
#
# **Entrada/Salida:**
# - `deposit`, `rate`, `threshold`: integer
# - retorno: integer

# %%
def solucion(deposit, rate, threshold):
    pass

# %% [markdown]
# ## Reto 3: Círculo de Números
# **Tarea:**
# Considera números del `0` al `n - 1` escritos en círculo. Dado `n` y `firstNumber`, encuentra el número en la posición diametralmente opuesta.
#
# **Ejemplo:**
# `n = 10, firstNumber = 2` -> `7`
#
# **Entrada/Salida:**
# - `n`: integer (siempre par), `firstNumber`: integer
# - retorno: integer

# %%
def solucion(n, firstNumber):
    pass

# %% [markdown]
# ## Reto 4: Cuadrados Diferentes
# **Tarea:**
# Dada una matriz rectangular de dígitos, calcula el número de cuadrados `2 x 2` únicos dentro de ella.
#
# **Ejemplo:**
# `matrix = [[1, 2, 1], [2, 2, 2], [2, 2, 2], [1, 2, 3], [2, 2, 1]]` -> `6`
#
# **Entrada/Salida:**
# - `matrix`: array.array.integer
# - retorno: integer

# %%
def solucion(matrix):
    pass

# %% [markdown]
# ## Reto 5: Ceros Finales del Factorial
# **Tarea:**
# Dado un entero `n`, devuelve la cantidad de ceros al final de `n!`.
#
# **Ejemplo:**
# `n = 5` -> `1` (120 tiene un cero final).
#
# **Entrada/Salida:**
# - `n`: integer
# - retorno: integer

# %%
def solucion(n):
    pass
