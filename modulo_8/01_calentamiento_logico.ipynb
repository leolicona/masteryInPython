# %% [markdown]
# <a href="https://colab.research.google.com/github/leolicona/masteryInPython/blob/main/modulo_8/01_calentamiento_logico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Bootcamp: Calentamiento Lógico

# %% [markdown]
# ## Reto 1: ZigZag
# **Tarea:**
# Una tripleta `(a, b, c)` es un zigzag si `a < b > c` o `a > b < c`.
# Dado un array de enteros `numbers`, tu tarea es construir un array de longitud `numbers.length - 2` donde el `i`-ésimo elemento es `1` si la tripleta `(numbers[i], numbers[i + 1], numbers[i + 2])` es un zigzag, y `0` en caso contrario.
#
# **Ejemplo:**
# `numbers = [1, 2, 1, 3, 4]` -> `[1, 1, 0]`
#
# **Entrada/Salida:**
# - `numbers`: array.integer (3 <= longitud <= 100)
# - retorno: array.integer

# %%
def solucion(numbers):
    pass

# %% [markdown]
# ## Reto 2: Reorganización de Palíndromo
# **Tarea:**
# Determina si los caracteres de una cadena se pueden reorganizar para formar un palíndromo.
#
# **Ejemplo:**
# `inputString = "aabb"` -> `True`
#
# **Entrada/Salida:**
# - `inputString`: string
# - retorno: boolean

# %%
def solucion(inputString):
    pass

# %% [markdown]
# ## Reto 3: Secuencia Casi Creciente
# **Tarea:**
# Determina si es posible obtener una secuencia estrictamente creciente eliminando no más de un elemento del array.
#
# **Ejemplo:**
# `sequence = [1, 3, 2, 1]` -> `False`
# `sequence = [1, 3, 2]` -> `True`
#
# **Entrada/Salida:**
# - `sequence`: array.integer
# - retorno: boolean

# %%
def solucion(sequence):
    pass

# %% [markdown]
# ## Reto 4: Suma de Elementos de Matriz
# **Tarea:**
# Una matriz de enteros representa un edificio. Un `0` significa que la habitación está embrujada. Te niegas a entrar a una habitación embrujada o a cualquier habitación que esté directamente debajo de una. Calcula la suma total de las habitaciones aptas para ti.
#
# **Ejemplo:**
# `matrix = [[0, 1, 1, 2], [0, 5, 0, 0], [2, 0, 3, 3]]` -> `9`
#
# **Entrada/Salida:**
# - `matrix`: array.array.integer
# - retorno: integer

# %%
def solucion(matrix):
    pass

# %% [markdown]
# ## Reto 5: Todas las Cadenas más Largas
# **Tarea:**
# Dado un array de cadenas, devuelve otro array que contenga todas sus cadenas de mayor longitud.
#
# **Ejemplo:**
# `inputArray = ["aba", "aa", "ad", "vcd", "aba"]` -> `["aba", "vcd", "aba"]`
#
# **Entrada/Salida:**
# - `inputArray`: array.string
# - retorno: array.string

# %%
def solucion(inputArray):
    pass
