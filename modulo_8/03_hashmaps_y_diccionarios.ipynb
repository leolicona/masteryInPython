# %% [markdown]
# <a href="https://colab.research.google.com/github/YOUR_USERNAME_AQUI/masteryInPython/blob/main/modulo_8/03_hashmaps_y_diccionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Bootcamp: Hashmaps y Diccionarios

# %% [markdown]
# ## Reto 1: Agrupar Anagramas
# **Tarea:**
# Agrupa los anagramas juntos. Puedes devolver la respuesta en cualquier orden.
#
# **Ejemplo:**
# `strs = ["eat","tea","tan","ate","nat","bat"]` -> `[["bat"],["nat","tan"],["ate","eat","tea"]]`
#
# **Entrada/Salida:**
# - `strs`: array.string
# - retorno: array.array.string

# %%
def solucion(strs):
    pass

# %% [markdown]
# ## Reto 2: Contiene Números Cercanos
# **Tarea:**
# Dado un array de enteros `nums` y un entero `k`, determina si existen dos índices distintos `i` y `j` tales que `nums[i] == nums[j]` y la diferencia absoluta entre `i` y `j` es menor o igual a `k`.
#
# **Ejemplo:**
# `nums = [0, 1, 2, 3, 5, 2], k = 3` -> `True`
#
# **Entrada/Salida:**
# - `nums`: array.integer, `k`: integer
# - retorno: boolean

# %%
def solucion(nums, k):
    pass

# %% [markdown]
# ## Reto 3: Siguen el Patrón
# **Tarea:**
# Dado un array `strings` y un array `patterns`, determina si siguen exactamente el mismo patrón de asignación 1 a 1.
#
# **Ejemplo:**
# `strings = ["cat", "dog", "dog"], patterns = ["a", "b", "b"]` -> `True`
# `strings = ["cat", "dog", "doggy"], patterns = ["a", "b", "b"]` -> `False`
#
# **Entrada/Salida:**
# - `strings`, `patterns`: array.string
# - retorno: boolean

# %%
def solucion(strings, patterns):
    pass

# %% [markdown]
# ## Reto 4: ¿Es solución Criptográfica?
# **Tarea:**
# Un criptaritmo es un acertijo donde se emparejan letras con dígitos. Dado un array `crypt` de 3 strings y una `solution` 2D, verifica si `palabra1 + palabra2 = palabra3` matemáticamente (sin ceros a la izquierda).
#
# **Ejemplo:**
# `crypt = ["SEND", "MORE", "MONEY"], solution = [['O', '0'], ['M', '1'], ...]` -> `True`
#
# **Entrada/Salida:**
# - `crypt`: array.string, `solution`: array.array.char
# - retorno: boolean

# %%
def solucion(crypt, solution):
    pass

# %% [markdown]
# ## Reto 5: Primer Duplicado
# **Tarea:**
# Dado un array `a` con números entre `1` y `a.length`, encuentra el primer número duplicado cuya segunda ocurrencia tenga el índice mínimo.
#
# **Ejemplo:**
# `a = [2, 1, 3, 5, 3, 2]` -> `3`
#
# **Entrada/Salida:**
# - `a`: array.integer
# - retorno: integer

# %%
def solucion(a):
    pass
