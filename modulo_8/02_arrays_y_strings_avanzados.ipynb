# %% [markdown]
# <a href="https://colab.research.google.com/github/YOUR_USERNAME_AQUI/masteryInPython/blob/main/modulo_8/02_arrays_y_strings_avanzados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Bootcamp: Arrays y Strings Avanzados

# %% [markdown]
# ## Reto 1: Suma de Dos (Two Sum)
# **Tarea:**
# Devuelve los índices de los dos números que sumados den como resultado `target`.
#
# **Ejemplo:**
# `nums = [2,7,11,15], target = 9` -> `[0,1]`
#
# **Entrada/Salida:**
# - `nums`: array.integer, `target`: integer
# - retorno: array.integer

# %%
def solucion(nums, target):
    pass

# %% [markdown]
# ## Reto 2: ¿Son Similares?
# **Tarea:**
# Dos arrays se consideran similares si uno puede obtenerse del otro intercambiando a lo sumo un par de elementos en uno de los arrays. Comprueba si dos arrays son similares.
#
# **Ejemplo:**
# `a = [1, 2, 3], b = [2, 1, 3]` -> `True`
# `a = [1, 2, 2], b = [2, 1, 1]` -> `False`
#
# **Entrada/Salida:**
# - `a`, `b`: array.integer
# - retorno: boolean

# %%
def solucion(a, b):
    pass

# %% [markdown]
# ## Reto 3: Diferencia Adyacente Máxima
# **Tarea:**
# Encuentra la diferencia absoluta máxima entre cualquiera de sus elementos adyacentes.
#
# **Ejemplo:**
# `inputArray = [2, 4, 1, 0]` -> `3`
#
# **Entrada/Salida:**
# - `inputArray`: array.integer
# - retorno: integer

# %%
def solucion(inputArray):
    pass

# %% [markdown]
# ## Reto 4: Invertir entre Paréntesis
# **Tarea:**
# Escribe una función que invierta los caracteres (posiblemente anidados) que estén entre paréntesis dentro del string. Las cadenas siempre estarán bien formadas.
#
# **Ejemplo:**
# `inputString = "foo(bar)baz"` -> `"foorabbaz"`
#
# **Entrada/Salida:**
# - `inputString`: string
# - retorno: string

# %%
def solucion(inputString):
    pass

# %% [markdown]
# ## Reto 5: Ordenar por Altura
# **Tarea:**
# Algunas personas están de pie en una fila. Hay árboles entre ellos que no pueden ser movidos. Reordena a las personas por sus alturas en orden no descendente sin mover los árboles. Los árboles están representados por `-1`.
#
# **Ejemplo:**
# `a = [-1, 150, 190, 170, -1, -1, 160, 180]` -> `[-1, 150, 160, 170, -1, -1, 180, 190]`
#
# **Entrada/Salida:**
# - `a`: array.integer
# - retorno: array.integer

# %%
def solucion(a):
    pass
