# %% [markdown]
# <a href="https://colab.research.google.com/github/YOUR_USERNAME_AQUI/masteryInPython/blob/main/modulo_8/05_retos_de_entrevistas_tecnicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Bootcamp: Entrevistas Técnicas

# %% [markdown]
# ## Reto 1: Paréntesis Válidos
# **Tarea:**
# Dada una cadena `s` que contiene solo `()[]{}` determina si es válida usando una Pila (Stack).
#
# **Ejemplo:**
# `s = "()[]{}"` -> `True`
#
# **Entrada/Salida:**
# - `s`: string
# - retorno: boolean

# %%
def solucion(s):
    pass

# %% [markdown]
# ## Reto 2: Primer Carácter No Repetido
# **Tarea:**
# Dada una cadena `s` de letras minúsculas, encuentra y devuelve la primera instancia de un carácter que no se repita. Si no hay ninguno, devuelve `'_'`.
#
# **Ejemplo:**
# `s = "abacabad"` -> `'c'`
#
# **Entrada/Salida:**
# - `s`: string
# - retorno: char

# %%
def solucion(s):
    pass

# %% [markdown]
# ## Reto 3: Rotar Imagen
# **Tarea:**
# Tienes una matriz 2D `n x n` que representa una imagen. Rota la imagen 90 grados a la derecha. Debes hacerlo *in-place* (sin crear otra matriz).
#
# **Ejemplo:**
# `a = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]` -> `[[7, 4, 1], [8, 5, 2], [9, 6, 3]]`
#
# **Entrada/Salida:**
# - `a`: array.array.integer
# - retorno: array.array.integer

# %%
def solucion(a):
    pass

# %% [markdown]
# ## Reto 4: Sudoku 2
# **Tarea:**
# Verifica si la cuadrícula dada `grid` representa un tablero de Sudoku 9x9 válido (sin repeticiones en filas, columnas ni bloques 3x3).
#
# **Entrada/Salida:**
# - `grid`: array.array.char
# - retorno: boolean

# %%
def solucion(grid):
    pass

# %% [markdown]
# ## Reto 5: Fusionar Intervalos
# **Tarea:**
# Dado un array de `intervals` donde `intervals[i] = [inicio, fin]`, fusiona todos los intervalos que se superpongan.
#
# **Ejemplo:**
# `intervals = [[1,3],[2,6],[8,10],[15,18]]` -> `[[1,6],[8,10],[15,18]]`
#
# **Entrada/Salida:**
# - `intervals`: array.array.integer
# - retorno: array.array.integer

# %%
def solucion(intervals):
    pass
