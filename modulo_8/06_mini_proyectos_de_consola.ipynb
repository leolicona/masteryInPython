# %% [markdown]
# <a href="https://colab.research.google.com/github/YOUR_USERNAME_AQUI/masteryInPython/blob/main/modulo_8/06_mini_proyectos_de_consola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Bootcamp: Proyectos / Diseño de Sistemas

# %% [markdown]
# ## Reto 1: Diseñar Gato (Tic-Tac-Toe)
# **Tarea:**
# Implementa `TicTacToe(n)` para inicializar un tablero `n x n`. Implementa `move(row, col, player)` que devuelva `1` si el jugador 1 gana, `2` si el jugador 2 gana, y `0` si nadie ha ganado aún.
#
# **Entrada/Salida:**
# - `row`, `col`, `player`: integer
# - retorno: integer

# %%
class TicTacToe:
    def __init__(self, n: int):
        pass
    def move(self, row: int, col: int, player: int) -> int:
        pass

# %% [markdown]
# ## Reto 2: Buscaminas (Minesweeper)
# **Tarea:**
# Dada una matriz booleana donde `True` significa que hay una mina, crea una nueva matriz donde cada celda contenga el número de minas en las celdas vecinas (incluyendo diagonales).
#
# **Ejemplo:**
# `matrix = [[True, False, False], [False, True, False], [False, False, False]]` -> `[[1, 2, 1], [2, 1, 1], [1, 1, 1]]`
#
# **Entrada/Salida:**
# - `matrix`: array.array.boolean
# - retorno: array.array.integer

# %%
def solucion(matrix):
    pass

# %% [markdown]
# ## Reto 3: Box Blur (Difuminado de Imagen)
# **Tarea:**
# Debes difuminar una imagen. Cada cuadrado de píxeles `3x3` debe promediarse para producir un solo píxel en el centro. Devuelve la matriz difuminada.
#
# **Entrada/Salida:**
# - `image`: array.array.integer
# - retorno: array.array.integer

# %%
def solucion(image):
    pass

# %% [markdown]
# ## Reto 4: Números en Espiral
# **Tarea:**
# Construye una matriz cuadrada de tamaño `n x n` que contenga enteros del `1` al `n * n` en un orden de espiral, comenzando desde arriba a la izquierda en dirección horaria.
#
# **Ejemplo:**
# `n = 3` -> `[[1, 2, 3], [8, 9, 4], [7, 6, 5]]`
#
# **Entrada/Salida:**
# - `n`: integer
# - retorno: array.array.integer

# %%
def solucion(n):
    pass

# %% [markdown]
# ## Reto 5: Nombramiento de Archivos
# **Tarea:**
# Se te da un array de nombres de archivos deseados. Si dos archivos comparten nombre, al segundo se le agrega `(k)`, donde `k` es el entero positivo más pequeño para que el nombre sea único.
#
# **Ejemplo:**
# `names = ["doc", "doc", "image", "doc(1)", "doc"]` -> `["doc", "doc(1)", "image", "doc(1)(1)", "doc(2)"]`
#
# **Entrada/Salida:**
# - `names`: array.string
# - retorno: array.string

# %%
def solucion(names):
    pass
